# %% [markdown]
# # Data Engineering using OpenCV Python
# ## Image to  Pencil Sketch

# %%
import cv2

# %%
image=cv2.imread('dog_image.jpg')
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2.imwrite('dog_grayimage.jpg',gray_image)
# Out:
# True

# %% [markdown]
# ![dog_image.jpg](attachment:dog_image.jpg)

# %% [markdown]
# ![dog_grayimage.jpg](attachment:dog_grayimage.jpg)

# %%
inverted=255-gray_image
blurred = cv2.GaussianBlur(inverted,(21,21),0)
cv2.imwrite("dog_blurred.jpg",blurred)
# Out:
# True

# %% [markdown]
# ![dog_blurred.jpg](attachment:dog_blurred.jpg)

# %%
invertedblur = 255-blurred
pencilsketch = cv2.divide(gray_image,invertedblur,scale=256.0)
cv2.imwrite("dog_sketched.jpg",pencilsketch)
# Out:
# True

# %% [markdown]
# ![dog_sketched.jpg](attachment:dog_sketched.jpg)
